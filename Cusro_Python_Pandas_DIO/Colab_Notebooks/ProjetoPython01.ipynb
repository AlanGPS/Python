# %%
print("Olá mundo!!!")
# Out:
# Olá mundo!!!

# %%
print("Estou aprendendo Python.")
# Out:
# Estou aprendendo Python.

# %%
"Estou aprendendo Python."
# Out:
# 'Estou aprendendo Python.'

# %%
#Esse é um comentário em Python...

# Soma:

1 + 1
# Out:
# 2

# %%
# Subtração:

10 - 2
# Out:
# 8

# %%
# Multiplicação:

2 * 2
# Out:
# 4

# %%
# Divisão:

10/2
# Out:
# 5.0

# %%
a = 4

b = 5

# %%
a + b
# Out:
# 9

# %%
# Crinado uma variável do tipo String

frase = "Python para análise de dados."

# %%
frase[0]
# Out:
# 'P'

# %%
frase[0:10]
# Out:
# 'Python par'

# %%
frase[10:]
# Out:
# 'a análise de dados.'

# %%
frase[:17]
# Out:
# 'Python para análi'

# %%
frase.count("dados")
# Out:
# 1

# %%
frase.upper()
# Out:
# 'PYTHON PARA ANÁLISE DE DADOS.'

# %%
frase.lower()
# Out:
# 'python para análise de dados.'

# %%
frase.replace("Python","Vida")
# Out:
# 'Vida para análise de dados.'

# %%
frase = frase.upper()

# %%
frase
# Out:
# 'PYTHON PARA ANÁLISE DE DADOS.'

# %%
frase = frase.replace("DADOS","estruturas de dados utilizando o Pandas")
print(frase)
# Out:
# PYTHON PARA ANÁLISE DE estruturas de dados utilizando o Pandas.

# %%
frase = frase.upper()
print(frase)
# Out:
# PYTHON PARA ANÁLISE DE ESTRUTURAS DE DADOS UTILIZANDO O PANDAS.
